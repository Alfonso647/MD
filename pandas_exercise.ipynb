# %% [markdown]
# Nombre y apellidos = Alfonso Íñiguez Cortés \
# gmail: aic35@alu.ua.es \
# Grupo: 3

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Importamos pandas

# %%
import pandas as pd

# %% [markdown]
# #### Creación dataframe

# %%
# Create a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

# Creamos el dataframe
df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4    Emily   45      Phoenix

# %% [markdown]
# ## 2. Acceso a DataFrames

# %% [markdown]
# Tenemos diversas formas de acceder a los DataFrames.

# %% [markdown]
# ### 2.1 Acceso a columnas individuales
