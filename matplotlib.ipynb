# %% [markdown]
# Nombre y apellidos = Alfonso Íñiguez Cortés \
# gmail: aic35@alu.ua.es \
# Grupo: 3

# %% [markdown]
# ## 1. Matplotlib

# %% [markdown]
# `Matplotlib` es una librería de trazado orientada a visualización de datos, análisis de datos... Está diseñada para crear gráficos estáticos, animados e interactivos en 2D y 3D con alta calidad. Basada en la sintaxis de MATLAB, permite personalizar cada elemento gráfico, siendo esencial en ciencia de datos y análisis numérico junto con NumPy.

# %% [markdown]
# ### 1.1 Importación Matplotlib

# %% [markdown]
# Vamos a importar la librerías necesarias de cara a usarlas a lo largo del cuaderno:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2 Creación de una gráfica

# %% [markdown]
# Vamos a crear nuestra primera gráfica empleando las funciones que nos ofrece
# `Matplotlib`. Para crear una gráfica, usamos la función `plot()`. Esta función recibe como parámetro los puntos que se van a representar, en este caso recibe dos argumentos que se refieren a el ejex y ejey. Además de `plot()`, podemos usar varias funciones para personalizar y mostrar nuestra gráfica. Por ejemplo, tenemos:
# - plt.figure(): Esta función define el tamaño de nuestra gráfica. Si no usamos esta función, se crea un tamaño de gráfica por defecto
# - plt.show(): Esta función es necesaria si queremos mostrar por pantalla nuestro plot
#
# Vamos a ver algunos ejemplos creando algunas gráficas simples:

# %%
eje_x = [1, 2, 3, 4, 5]
eje_y = [3, 3, 3, 5, 7]

plt.figure(figsize=(10, 5)) 
plt.plot(eje_x, eje_y) 
plt.show()

# %% [markdown]
# En el ejemplo anterior, hemos creado una función lineal, pero esta librería nos ofrece diferenes formas de mostrar las gráficas. Un ejemplo es usando la función `scatter()`. Esta función produce un gráfico de dispersión y toma los mismos parámetros que `plot()`, que son el ejex y el ejey.
#
# Vamos a crear un gráfico de dispersión a modo de ejemplo:

# %%
eje_x = [1, 2, 3, 4, 5]
eje_y = [3, 3, 3, 5, 7]

plt.figure(figsize=(10, 5)) 
plt.scatter(eje_x, eje_y) 
plt.show()

# %% [markdown]
# Vamos a seguir explorando las distintas formas de representación de gráficas que nos ofrece la librería. En este caso, vamos a estudiar como graficar en 3D. Para ello necestiamos nuevamente la función `plot()`, pero en lugar de tomar dos arguementos, toma tres. Estos se refierene al ejex, ejey, y ejez para añadir profundiad y crear las tres dimensiones.
#
# Vamos a crear un ejemplo de un gráfico en 3D:

# %%
fig = plt.figure(figsize=(10, 5)) 
ax = fig.add_subplot(111, projection='3d') 

x = [0, 2, 2, 0, 0, 0, 2, 2, 2, 2, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0]   # Coordenadas en 3D
y = [0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2]
z = [0, 0, 0, 0, 0, 2, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 2, 2, 2, 2]

ax.plot(x, y, z) 
plt.show()

# %% [markdown]
# Otra opción de la que disponemos para mostrar datos es graficando una gráfica de barras. Para ello no usamos plot, si no que usamos la función `bar()`. Esta función nuevamente recibe como argumentos los datos del ejex y ejey.
#
# Vamos a crear un ejemplo de un gráfico de barras emplenado las herramientas comentadas:

# %%
eje_x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
eje_y = [0, 2, 4, 8, 10, 8, 4, 2, 0]

plt.figure(figsize=(10, 5)) 
plt.bar(eje_x, eje_y) 
plt.show()

# %% [markdown]
# Finalmente, vamos a estudiar como graficar un histograma. Para ello, `Matplotlib` nos ofrece la función `hist()`, la cual recibe como argumentos los datos. Un histograma es una
# representación gráfica de la distribución de un conjunto de datos numéricos y continuos, organizada mediante barras verticales, donde se muestra la frecuencia con la que suceden los valores dentro de intervalos. Luego esta función recibe dos argumentos, que son dichos datos e intervalos.
#
# Vamos a crear un histograma a modo de ejemplo:

# %%
np.random.seed(2)
data = np.random.randn(100) # Creamod datos aleatorios

plt.hist(data, bins=45) 

plt.show()

# %% [markdown]
# ## 3. Personalizar las gráficas

# %% [markdown]
# A la hora de presentar nuestros trabajos, es necesario que todo sea visualmente accesible tanto para el trabajo grupal como para mostrar resultados con mucha simplicidad. `Matplotlib` nos ofrece diversas formas de personalizar nuestros gráficos de cara a hacerlos accesibles, escalables... En esta sección vamos a estudiar diferentes formas de personalizacion de gráficas

# %% [markdown]
# ### 3.1 Añadir un título

# %% [markdown]
# El recurso más importante es ser capaz de nombrar nuestra gráfica. Es el primer paso a la hora de presentar los plots a los demás para que entiendad que es lo que estamos graficando exactamente. Para ello, usamos la función `title()` que recibe como argumento   el titulo de la gráfica.
#
# Vamos a poner varios ejemlos en los cuales nombramos a nuestras gráficas:

# %%
# Generar 100 puntos entre -10 y 10
x = np.linspace(0, 30, 100) 
y = np.sin(x) 

plt.plot(x, y)
plt.title('Función seno')
plt.show()

# %% [markdown]
# ### 3.2 Añadir etiquetas

# %% [markdown]
# Otro recurso sumamente importante es añadir nombres a los ejes de la figura que estemos mostrando. Es importante mostar que estamos comparndo con que para que las gráficas sean entendibles. Para esto, usamos las siguientes funciones:
#
# - `xlabel()`: Para el ejex, recibe como parámetro la etiqueta del ejex
# - `ylabel()`: Para el ejex, recibe como parámetro la etiqueta del ejey
#
# Vamos a crar otro ejemplo de gráfica para mostar el funcionamieto de estas funciones:

# %%
# Generar 100 puntos entre -10 y 10
x = np.linspace(0, 30, 100) 
y = np.cos(x) 

plt.plot(x, y)
plt.title('Función coseno')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.show()

# %% [markdown]
# ### 3.3 Añadir una leyenda

# %% [markdown]
# Es también muy importante definir las leyendas de las gráficas. Sobretodo cuando  en una misma gráfica mostramos vamos a mostrar varias representaciones. La leyenda de un gráfico es un elemento explicativo (suele ser un cuadro pequeño) que identifica qué información representa cada linea. Para implementar las leyendas usamos la función: `legend()`. En el caso de las leyendas, especificamos el nombre de la función que van a representar en el plot de la misma añadiendole un parámetro:
#
# - label="Nombre de la etiqueta"
#
# Volviendo a los ejemplos anteriores, vamos a mostrar la función seno y coseno juntas. Para mostrar plots en la misma gráfica, simplemente usamos la función `plot()` para la función coseno(x) y para seno(x).

# %%
x = np.linspace(0, 30, 100) 
y_sin = np.sin(x)
y_cos = np.cos(x) 

plt.figure(figsize=(10, 5)) 

# función seno
plt.plot(x, y_sin, label='seno')
plt.xlabel('x')
plt.ylabel('sin(x)')

# Función coseno
plt.plot(x,y_cos, label='coseno')
plt.xlabel('x')
plt.ylabel('cos(x)')

# Representamos la gráfica
plt.title('Representación seno vs coseno')
plt.legend()
plt.show()

# %% [markdown]
# ### 3.4 Personzalizar el color, estilo de línea y estilo de marcador

# %% [markdown]
# Notamos como en el ejemplo anterior, al mostar dos gráficas y no le especificamos nada más `Matplotlib` cambia los colores del segundo plot con respecto al primero. Esto es para que se distingan y por defecto le da al primer plot el color azul y al segundo el color naranja. En este apartado vamos a estudiar como modificar el estilo de linea, color... Para ello, especificamos estas personalizaciones dentro de la propia función `plot()`:
#
# ```python
# plt.plot(x, y, color = '', linestyle= '', marker= '')
# ```
# Vemos como tenemos que darle valor a los siguientes argumentos:
# - color -> Color de línea
# - linestyle -> Estilo de línea
# - marker -> Estilo de marcador
#
# Vamos a poner varios ejemplos de gráficas con nuestros propios estilos. Para mostrar curvas más visuales vamos a emplear gráficas polares:
# -> En lugar de usar coordenadas X,Y; usamos un ángulo ``θ`` y una distancia ``r`` desde el centro. Vamos a seguir los siguientes pasos:
#
# - Para calcular θ:
# -> Calculamos puntos desde 0 a 2π puesto que queremos cubrir un giro completo
#
# - Para calcular r
# -> Depende de que curva queremos representar
#
# - Convertimos a coordenadas cartesianas
# -> Una vez que tenemos las distancias r calculadas, vamos a pasarlas a coordenadas cartesianas con el objetivo de una mejor representación. En este caso :
# 1. x = r * cos(θ)    # Proyección horizontal
# 2. y = r * sin(θ)    # Proyección vertical
#
# Una vez tenemos x e y, graficamos como lo hemos estado haciendo hasta ahora
#
# Curvas de referencia: \
# https://matematicasiesoja.wordpress.com/wp-content/uploads/2020/04/curvasmaravillosas.pdf

# %%
angulo = np.linspace(0, 2*np.pi, 1000)
r = np.sin(6 * angulo)

# Pasamos a coordenadas cartesianas
x = r * np.cos(angulo)
y = r * np.sin(angulo)

plt.plot(x, y, color='pink', linestyle='-.', marker='.')
plt.title('Folio')
plt.show()

# %% [markdown]
# Vemos como hemos usado :
# - color = 'pink' (le da el color rosa)
# - linestyle = '-.' (los puntos se unen con guión y punto)
# - marker = '.' (cada punto se representa con un punto)
#
# Vamos a poner otro ejemplo quitando el marcador para que se aprecie más el parámetro de `linestyle`:

# %%
angulo = np.linspace(0, 2*np.pi, 1000)
r = np.sin(4 * angulo)

# Pasamos a coordenadas cartesianas
x = r * np.cos(angulo)
y = r * np.sin(angulo)

plt.plot(x, y, color='blue', linestyle='-.')
plt.title('Folio')
plt.show()

# %% [markdown]
# ## 4. Múltiples gráficas

# %% [markdown]
# ### 4.1 Versión en bruto

# %% [markdown]
# `Matplotlib` nos permite crear varias gráficas dentro de una misma figura. Esto lo conseguimos con la función `subplot()`, la cual recibe los siguentes parámetros:
# - Número de filas
# - Número de columnas
# - Índice del grafo
#
# Vamos a ver un ejemplo:

# %%
# Primer plot
angulo = np.linspace(0, 5*np.pi, 100)
r = 2 * np.exp(0.3*angulo)

# Pasamos a coordenadas cartesianas
x = r * np.cos(angulo)
y = r * np.sin(angulo)


plt.subplot(1,2,1)
plt.plot(x, y, color='red', linestyle=':')
plt.title('Espiral logarítmica')


# Segundo plot
r = 0.8 * angulo
# Pasamos a coordenadas cartesianas
x = r * np.cos(angulo)
y = r * np.sin(angulo)

plt.subplot(1,2,2)
plt.plot(x, y, color='green', linestyle='--')
plt.title('Espiral de Arquímedes')
plt.show()

# %% [markdown]
# Vemos como hemos crado dos espirales. Para ello hemos tenido que aumentar el valor del ángulo con el objetivo de que curbiera mas de una sola vuelta completa. En este caso, hemos usado subplots de la siguiente forma:
#
# - subplot(1,2,1)
# - subplot(1,2,2)
#
# Esto nos crea una figura de 1 fila y 2 columnas como podemos observar en el resultado. En el siguiente apartado vamos a esutudiar com ocrear múltiples gráficos usando objetos

# %% [markdown]
# ### 4.2 Versión formateada

# %% [markdown]
# Usar objetos para crear diversos gráficos es una de las formas mas óptimas de hacerlo. Vamos a explicar el proceso de forma detallada:
#
# El primer paso es obtener los objetos: `fig` y `ax` de la siguiente forma:
# ```python
# fig, ax = plt.subplots(1, 2, figsize=(10, 5)) # Create a figure and 2 axes.
# ```
# En este caso, tenemos una sola figura y dos ejes (lugares individuales donde se dibujan cada gráfico) es decir que vamos a dibujar dos gráficas dentro de una figura.
#
# Para personalizar cada gráfico, usamos el objeto ax y su índice, es decir, si queremos acceder al primer "mini"-gráfico usamos: ax[0]. Luego, `Matplotlib` nos ofrece una serie de funciones para modificar cada gráfica:
# - .plot -> Crear el gráfico (usando plot)
# - .set_title -> Añadir un título
# - .set_xlabel & .set_ylabel -> Añadir título a los ejes
# - .legend -> Mostrar las leyendas
#
# Vamos a mostrar un ejemplo de como usar objetos para crear varias gráficas:

# %%
angulo = np.linspace(1, 15*np.pi, 100)

# Creamos los objetos
fig, ax = plt.subplots(1, 2, figsize=(10, 5))


# PRIMER PLOT
r = 1 * (np.sqrt(angulo))
# Pasamos a coordenadas cartesianas
x = r * np.cos(angulo)
y = r * np.sin(angulo)

ax[0].plot(x, y, label='Femat', color='Orange', linestyle='-.') 
ax[0].set_title('Espiral de Fermat') 
ax[0].set_xlabel('eje x')
ax[0].set_ylabel('eje y')
ax[0].legend()

# SEGUNDO PLOT
r = 1 / (np.sqrt(angulo))
# Pasamos a coordenadas cartesianas
x = r * np.cos(angulo)
y = r * np.sin(angulo)

ax[1].plot(x, y, label='Lituus', color = 'Black', linestyle='--') 
ax[1].set_title('Espiral de Lituus')
ax[1].set_xlabel('eje x')
ax[1].set_ylabel('eje y')
ax[1].plot(y-1, x+1, label='Lituus', color = 'red', linestyle=':') 
ax[1].legend()
plt.show()

# %% [markdown]
# Otra función que nos permite esta librería es la de guardar nuestras gráficas en distintos formatos de archivos. Para ello, usamos la función `savefig()`. Esta función recibe como argumento el nombre que va a tener el archivo guardado y en qur formato (jpg, png...) Vamos a guardar una gráficaen un archivo llamado `plot.png`:

# %%
angulo = np.linspace(1, 5*np.pi, 100)

r = 4 * (1 - np.cos(angulo))
# Pasamos a coordenadas cartesianas
x = r * np.cos(angulo)
y = r * np.sin(angulo)

plt.figure(figsize=(10, 5)) 
plt.plot(x, y, label='Cardioide1', color='red')
plt.plot(x-11, y, label='Cardioide2', color='yellow')
plt.title('Cardiodide')
plt.xlabel('ejex')
plt.ylabel('ejey')
plt.axis('equal')  # AJustamos dimensiones de los ejes
plt.legend()
# Guardamos la figura
plt.savefig('plot.png')

# %% [markdown]
# ## 5. Seaborn y Matplotlib

# %% [markdown]
# En este apartado de la prácitca, vamos a estudiar la librería `Seaborn`. Esta biblioteca es de visualización de datos, y esta completamente basada en `Matplotlib`. Su función es proporcionarnos una interfaz de mayor nivel con el objetivo de mostrar gráficos de una forma mas visual y con más información. Cuando tenemos datos complejos, esta biblioteca es una óptima opción pueso que es capaz de visualizarlos. `Seaborn` también es comúnmente utilizada en análisi de datos y aprendizaje automático

# %% [markdown]
# ### 5.1 Instlación de Seaborn

# %% [markdown]
# Para instalar esta librería usamos el siguiente comando:

# %%
try:
    # !pip install seaborn
except:
    print('No se ha podido instalar Seaborn')

# %% [markdown]
# Ahora que lo tenemos instalado, vamos a importarlo para poder usarlo en el resto del cuaderno:

# %%
import seaborn as sns

# %% [markdown]
# ### 5.2 Cración de una gráfica

# %% [markdown]
# Vamos a esutidar que opciones nos permite `Seaborn` para crear diferentes gráficas. Para crear una gráfica simple, tenemos la función `lineplot()`. Esta función sería el equivalente a `plot()` de `Matplotlib`. La función tiene dos argumentos:
# - Eje x
# - Eje y
#
# `Seaborn` representa el eje y frente al eje x
#
# Vamos a crear nuestra primera gráfica con esta biblioteca:

# %%
x = np.linspace(-10, 10, 20)
plt.figure(figsize=(10,5))
y = x**2

sns.lineplot(x=x, y=y, color='Green', linestyle='-.', marker='d', label='Función')
plt.title('Función cuadrática')
plt.legend()
plt.show()

# %% [markdown]
# Además, `Seaborn` nos permite crar gráficas de barras, diagramas de dispersión, histogramas... Vamos a listar algunos funciones ofrecidas por esta biblioteca y luego vamos a mostrar varios ejemplos:
#
# - barplot
# - scatterplot
# - histplot
#
# Todas estas funciones representan el eje_y frente al eje_x. Vamos a poner varios ejemplos:

# %% [markdown]
# ##### BARPLOT

# %%
categorias = ['A', 'B', 'C', 'D']
valores = [10, 23, 17, 9]

# Graficar
sns.barplot(x=categorias, y=valores, linewidth=3, edgecolor='black', capsize=0.2)
plt.title('Barplot')
plt.show()

# %% [markdown]
# ##### SCATTERPLOT

# %%
x = np.random.rand(50) 
y = np.random.rand(50) 
sns.scatterplot(x=x, y=y, color='black', s=80, edgecolor = 'red')
plt.title('Scatterplot')
plt.show()

# %% [markdown]
# ##### HISTPLOT

# %%
datos = np.random.randn(3000)
sns.histplot(datos, bins=20, kde=True, color='purple')
plt.title('Histplot')
plt.show()

# %% [markdown]
# ### 5.3 Múltiples gráficas

# %% [markdown]
# Como ocurre en `Matplotlib`, `Seaborn` nos ofrece la función de crear múltiples gráficas en una misma figura. Para ello, usamos la función `subplots()`. Esta función recibe como parámetros:
# - Número de filas
# - Número de columnas
#
# Nos devuelve dos objetos: fig y ax.
# -> Fig se refiere a la figura completa
# -> ax se regire a los ejes individuales y para acceder a cada uno se hace con ax[número de índice] (ax[0] sería el primer gráfico)
#
# De esta forma podemos organizar varios gráficos en la misma ventana. Vamos a crear un ejemplo:

# %%
x = [1,6,5,4,3]
y = [2, 3, 4, 5, 6]
z = [5, 4, 6, 3, 7]
w = [1, 2, 1, 3, 2]

# Creamos figura con 2 subplots
fig, ax = plt.subplots(1, 2, figsize=(12,5))

# --------------------------
sns.lineplot(x=x, y=y, ax=ax[0], label='Linea 1', color='red')
sns.lineplot(x=x, y=z, ax=ax[0], label='Linea 2', color='blue')
ax[0].set_title('Lineas')
ax[0].set_xlabel('X')
ax[0].set_ylabel('Y')
ax[0].legend()

# --------------------------
sns.scatterplot(x=x, y=y, ax=ax[1], label='Puntos 1', color='green', s=80)
sns.scatterplot(x=x, y=w, ax=ax[1], label='Puntos 2', color='orange', s=80)
ax[1].set_title('Puntos')
ax[1].set_xlabel('X')
ax[1].set_ylabel('Y')
ax[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Ejercicios

# %% [markdown]
# Vamos a realizar 4 gráficos diferentes empleando como datos el DataFrame creado de la sección anterior. Vamos a importar las librerías necesarias para llevar a cabo los ejercicios:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Para ello, vamos primeramente a leer el DataFrame del archivo .csv para poder graficar sobre este:

# %%
df = pd.read_csv('dataset.csv')
print(df)
# Out:
#     ID    Nombre      Tipo  Distancia_UA   Radio   Orbita       Conexiones
# 0    1       Sol  Estrella        0.0000  696340   Centro  2,3,4,5,6,7,8,9
# 1    2  Mercurio   Planeta        0.3900    2439      Sol                1
# 2    3     Venus   Planeta        0.7200    6051      Sol                1
# 3    4    Tierra   Planeta        1.0000    6371      Sol             1,10
# 4    5     Marte   Planeta        1.5200    3389      Sol                1
# 5    6   Júpiter   Planeta        5.2000   69911      Sol             1,11
# 6    7   Saturno   Planeta        9.5800   58232      Sol             1,12
# 7    8     Urano   Planeta       19.2200   25362      Sol                1
# 8    9   Neptuno   Planeta       30.0500   24622      Sol                1
# 9   10      Luna  Satélite        0.0026    1737   Tierra                4
# 10  11    Europa  Satélite        5.2000    1560  Júpiter                6
# ...

# %% [markdown]
# Referencia de las paletas de colores: https://seaborn.pydata.org/generated/seaborn.color_palette.html

# %% [markdown]
# ### GRÁFICA 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('dataset.csv')

# Limpieza
df.columns = df.columns.str.strip()
df['Tipo'] = df['Tipo'].str.strip()

# Filtrar
estrellas = df[df['Tipo'] == 'Estrella']
planetas = df[df['Tipo'] == 'Planeta']
satelites = df[df['Tipo'] == 'Satélite']

fig, axes = plt.subplots(3, 1, figsize=(10, 12))

sns.barplot(data=estrellas, x='Nombre', y='Radio', hue='Nombre', palette='pastel', ax=axes[0], legend=False)
axes[0].set_title("Estrellas")

sns.barplot(data=planetas, x='Nombre', y='Radio', hue='Nombre', palette='husl', ax=axes[1], legend=False)
axes[1].set_title("Planetas")

sns.barplot(data=satelites, x='Nombre', y='Radio', hue='Nombre', palette='flare', ax=axes[2], legend=False)
axes[2].set_title("Satélites")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gráfica 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Leer dataset
df = pd.read_csv('dataset.csv')
df.columns = df.columns.str.strip()
df['Tipo'] = df['Tipo'].str.strip()

planetas = df[df['Tipo'] == 'Planeta']

# Crear figura
fig, axes = plt.subplots(2, 1, figsize=(12, 12))

# --------------------------
# Gráfica 1: Scatter + Line
sns.scatterplot(
    data=planetas,
    x='Distancia_UA',
    y='Radio',
    hue='Nombre',
    palette='tab10',
    s=200,
    ax=axes[0]
)

sns.lineplot(
    data=planetas,
    x='Distancia_UA',
    y='Radio',
    color='black',
    linestyle='--',
    ax=axes[0]
)

axes[0].set_title("Planetas: Radio vs Distancia (Scatter + Line)")
axes[0].set_xlabel("Distancia al Sol (UA)")
axes[0].set_ylabel("Radio (km)")
axes[0].legend()

# --------------------------
# Gráfica 2: Bar + Scatter (tipo “mejorado” sin hacks)
sns.barplot(
    data=planetas,
    x='Nombre',
    y='Distancia_UA',
    hue='Nombre',
    palette='husl',
    ax=axes[1],
    legend=False
)

sns.scatterplot(
    data=planetas,
    x='Nombre',
    y='Distancia_UA',
    color='black',
    s=100,
    ax=axes[1]
)

axes[1].set_title("Planetas: Distancia al Sol (Bar + Scatter)")
axes[1].set_xlabel("Nombre del Planeta")
axes[1].set_ylabel("Distancia al Sol (UA)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gráfica 3

# %%
# Segunda gráfica nueva: Satélites
fig, axes = plt.subplots(2, 1, figsize=(12, 12))

# --------------------------
# Gráfica 1: Radio vs Distancia (Scatter + Line)
sns.scatterplot(
    data=satelites,
    x='Distancia_UA',
    y='Radio',
    hue='Nombre',
    palette='tab10',
    s=200,
    ax=axes[0]
)
sns.lineplot(
    data=satelites,
    x='Distancia_UA',
    y='Radio',
    color='gray',
    linestyle='--',
    ax=axes[0]
)
axes[0].set_title("Satélites: Radio vs Distancia (Scatter + Line)", weight='bold')
axes[0].set_xlabel("Distancia al Planeta Padre (UA)")
axes[0].set_ylabel("Radio (km)")

# --------------------------
# Gráfica 2: Scatter con tamaño proporcional al Radio
x_positions = np.arange(len(satelites))
axes[1].scatter(
    x=x_positions,
    y=satelites['Distancia_UA'],
    s=satelites['Radio'] / 10,
    c=sns.color_palette("bright", len(satelites)),
    alpha=0.7,
    edgecolor='k'
)
axes[1].set_xticks(x_positions)
axes[1].set_xticklabels(satelites['Nombre'], rotation=45)
axes[1].set_title("Satélites: Distancia al Planeta Padre (Scatter tamaño proporcional al Radio)", weight='bold')
axes[1].set_xlabel("Nombre del Satélite")
axes[1].set_ylabel("Distancia al Planeta Padre (UA)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gráfica 4

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('dataset.csv')
df.columns = df.columns.str.strip()
df['Tipo'] = df['Tipo'].str.strip()

planetas = df[df['Tipo'] == 'Planeta']
satelites = df[df['Tipo'] == 'Satélite']

fig, axes = plt.subplots(2, 1, figsize=(12, 12))

# --------------------------
# Gráfica 1: Ranking planetas
sns.barplot(
    data=planetas,
    x='Nombre',
    y='Radio',
    hue='Nombre',
    palette='viridis',
    ax=axes[0],
    legend=False
)

sns.lineplot(
    data=planetas,
    x='Nombre',
    y='Radio',
    color='black',
    marker='o',
    ax=axes[0]
)

axes[0].set_title("Ranking de planetas por tamaño")
axes[0].set_xlabel("Planeta")
axes[0].set_ylabel("Radio")

# --------------------------
# Gráfica 2: Distribución satélites
sns.violinplot(
    data=satelites,
    x='Nombre',
    y='Radio',
    palette='Set2',
    ax=axes[1]
)

sns.stripplot(
    data=satelites,
    x='Nombre',
    y='Radio',
    color='black',
    size=8,
    ax=axes[1]
)

axes[1].set_title("Distribución de radios de satélites")
axes[1].set_xlabel("Satélite")
axes[1].set_ylabel("Radio")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21068\458600795.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('dataset.csv')
df.columns = df.columns.str.strip()
df['Tipo'] = df['Tipo'].str.strip()

fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# --------------------------
# Gráfica 1: Número de objetos por tipo
sns.countplot(
    data=df,
    x='Tipo',
    palette='pastel',
    ax=axes[0]
)

axes[0].set_title("Número de objetos por tipo")
axes[0].set_xlabel("Tipo")
axes[0].set_ylabel("Cantidad")

# --------------------------
# Gráfica 2: Número de objetos por órbita
sns.countplot(
    data=df,
    x='Orbita',
    palette='Set2',
    ax=axes[1]
)

axes[1].set_title("Número de objetos que orbitan cada cuerpo")
axes[1].set_xlabel("Cuerpo orbitado")
axes[1].set_ylabel("Cantidad")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21068\3286032177.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21068\3286032177.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('dataset.csv')
df.columns = df.columns.str.strip()
df['Tipo'] = df['Tipo'].str.strip()

# Quitamos el Sol (porque no orbita a nadie)
df2 = df[df['Orbita'] != 'Centro']

fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# --------------------------
# Gráfica 1: Conteo por órbita (filtrado)
sns.countplot(
    data=df2,
    x='Orbita',
    hue='Tipo',
    palette='bright',
    ax=axes[0]
)

axes[0].set_title("Objetos que orbitan cada cuerpo (por tipo)")
axes[0].set_xlabel("Cuerpo orbitado")
axes[0].set_ylabel("Cantidad")

# --------------------------
# Gráfica 2: Solo satélites
satelites = df[df['Tipo'] == 'Satélite']

sns.countplot(
    data=satelites,
    x='Orbita',
    palette='cool',
    ax=axes[1]
)

axes[1].set_title("Número de satélites por planeta")
axes[1].set_xlabel("Planeta")
axes[1].set_ylabel("Número de satélites")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21068\44252902.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('dataset.csv')
df.columns = df.columns.str.strip()
df['Tipo'] = df['Tipo'].str.strip()

fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# --------------------------
# Gráfica 1: Conteo cruzado Tipo vs Orbita
sns.countplot(
    data=df,
    x='Orbita',
    hue='Tipo',
    palette='Set1',
    ax=axes[0]
)

axes[0].set_title("Relación entre tipo y órbita")
axes[0].set_xlabel("Orbita")
axes[0].set_ylabel("Cantidad")

# --------------------------
# Gráfica 2: Proporción de tipos
sns.histplot(
    data=df,
    x='Tipo',
    hue='Tipo',
    multiple='stack',
    palette='pastel',
    ax=axes[1]
)

axes[1].set_title("Proporción de tipos en el sistema")
axes[1].set_xlabel("Tipo")
axes[1].set_ylabel("Frecuencia")

plt.tight_layout()
plt.show()
